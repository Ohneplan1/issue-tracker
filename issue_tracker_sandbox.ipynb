# %%
from sqlite3 import connect

# %%
connection = connect("issue_tracker.db")

# %%
add_issue(
    name="Staubsaugen", 
    description="Putze die Wohnung",
    due_date="2026-07-30",
    priority=1
)

# %%
get_issues()
# Out:
# [(1, 'Einkaufen', 'Kaufe Eier und Milch', '2026-04-23', 1),
#  (2, 'Staubsaugen', 'Putze die Wohnung', '2026-07-30', 1),
#  (3, 'Staubsaugen', 'Putze die Wohnung', '2026-07-30', 1),
#  (4, 'Staubsaugen', 'Putze die Wohnung', '2026-07-30', 1)]
